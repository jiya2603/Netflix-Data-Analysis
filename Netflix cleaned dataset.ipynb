# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv("file.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates( inplace= True)

# %%
df.shape
# Out:
# (7787, 11)

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(df.isnull())
plt.xlabel("Columns" )
plt.ylabel("Null Values")
plt.title("Heat Map for Null Values",fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Heat Map for Null Values')

# %%
dfc = df.copy()

# %%
dfc["Director"].fillna("Not Available", inplace = True)

# %%
dfc.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
dfc['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
dfc["Release_Date"]= pd.to_datetime(dfc["Release_Date"])
dfc.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%      Not Available
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
dfc["Release_Date"].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
dfc.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%      Not Available
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
dfc.groupby('Category')

# %%
dfc.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
plt.bar(dfc['Category'], height=5)
# Out:
# <BarContainer object of 7787 artists>

# %%
dfc.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%      Not Available
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
dfc.drop('Release_Date')

# %%
dfc [ (dfc['Category']== 'Movie') & (dfc['New_Date'].dt.year == 2020) ] #movies released in 2020
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
dfc[ (dfc['Category'] == 'TV Show') &(dfc['Country']=='India')]['Title'] #all TV shows' title released in India only
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
dfc['Director'].value_counts().head(11).drop('Not Available') #Top 10 directors to give highest no. of movies
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Shannon Hartman            8
# Name: Director, dtype: int64

# %%
dfc[(dfc['Category']=='Movie')&(dfc['Country']=='United Kingdom') | (dfc['Type']=='Dramas')] #drama type movies in UK
# Out:
#      Show_Id Category                       Title  \
# 4         s5    Movie                          21
# 7         s8    Movie                         187
# 19       s20    Movie                         '89
# 82       s83    Movie         2036 Origin Unknown
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7628   s7627    Movie                    Williams
# 7649   s7648    Movie               Without Gorky
# 7688   s7687    Movie      XV: Beyond the Tryline
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 4                             Robert Luketic
# 7                             Kevin Reynolds
# 19                             Not Available
# 82                             Hasraf Dulull
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %%
dfc[dfc['Cast']=='Giles Yeo']
# Out:
#      Show_Id Category                       Title  \
# 7615   s7614    Movie  Why Are We Getting So Fat?
#
#                                     Director       Cast         Country  \
# 7615  Milla Harrison-Hansley, Alicky Sussman  Giles Yeo  United Kingdom
#
#      Release_Date Rating Duration           Type  \
# 7615   2019-02-01  TV-14   50 min  Documentaries
#
#                                             Description   New_Date
# 7615  A Cambridge geneticist dispels misconceptions ... 2019-02-01

# %%
dfc['Cast'].value_counts().head(3) #highest casted actors
# Out:
# David Attenborough    18
# Samuel West           10
# Jeff Dunham            7
# Name: Cast, dtype: int64

# %%
dfc_new = dfc.dropna()

# %%
dfc_new[dfc_new['Cast'].str.contains('Tom Cruise')] #Cast having Tom Cruise in it
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description   New_Date
# 3860  Through chance, human action, past history and... 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %%
dfc['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#all Tv shows with Rating TV-G in country Canada
dfc[(dfc['Category']=='TV Show') & (dfc['Rating']=='TV-G') & (dfc['Country']=='Canada')]
# Out:
#      Show_Id Category                       Title       Director  \
# 1768   s1769  TV Show                   Dino Hunt  Not Available
# 2498   s2499  TV Show                  Goosebumps  Not Available
# 3728   s3729  TV Show  Lost & Found Music Studios  Not Available
# 4261   s4262  TV Show                   Mr. Young  Not Available
# 4346   s4347  TV Show          My Perfect Landing  Not Available
# 4590   s4591  TV Show                     Oh Yuck  Not Available
# 4905   s4905  TV Show            Ponysitters Club  Not Available
# 6709   s6708  TV Show               The Next Step  Not Available
#
#                                                    Cast Country Release_Date  \
# 1768                                                NaN  Canada   2017-08-04
# 2498                                         R.L. Stine  Canada   2014-11-19
# 3728  Victoria Baldesarra, Sarah Carmosino, Jordan C...  Canada   2016-12-03
# ...

# %%
# Shows who got R rating after 2016
dfc[ (dfc['Category']=='TV Show') & (dfc['Rating']=='R') & (dfc['New_Date'].dt.year > 2016)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description   New_Date
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %%
dfc['Year']= dfc['New_Date'].dt.year

# %%
dfc.sort_values(by ='Year', ascending= True).head() #sorting values according to year
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five         Not Available
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#      Release_Date Rating  Duration                                   Type  \
# ...

# %%
dfc[(dfc['Category']=='Movie')].sort_values(by='Year').head() #sorting movies according to year
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# 2041   s2042    Movie                Even the Rain         Icíar Bollaín
#
#                                                    Cast  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 2041  Luis Tosar, Gael García Bernal, Juan Carlos Ad...
#
#                     Country Release_Date Rating Duration  \
# 7115          United States   2008-01-01  TV-MA   81 min
# 3248                Denmark   2009-05-05  TV-MA  104 min
# ...

# %%
dfc[(( dfc['Category']=='TV Show') & (dfc['Country']=='Canada'))| (dfc['Category']=='TV Show') & (dfc['Country']=='Denmark')]
# Out:
#      Show_Id Category                                   Title  \
# 87       s88  TV Show                              21 Thunder
# 389     s390  TV Show                             Alias Grace
# 539     s540  TV Show                          Anne with an E
# 685     s686  TV Show                               Bad Blood
# 783     s784  TV Show                           Beast Legends
# ...      ...      ...                                     ...
# 7179   s7178  TV Show  Trailer Park Boys: The Animated Series
# 7253   s7252  TV Show                    True: Terrific Tales
# 7315   s7314  TV Show            Unabomber - In His Own Words
# 7485   s7484  TV Show                                 Warrior
# 7665   s7664  TV Show                            Workin' Moms
#
#                                                Director  \
# 87                                        Not Available
# 389                                       Not Available
# ...
